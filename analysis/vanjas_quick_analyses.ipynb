# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make tables easier to read
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 140)

CSV_PATH = "../data/data_clean.csv"

# %%
N_ROWS = 7828021 #1000000  #total rows 7 828 021

# %%
df = pd.read_csv(CSV_PATH, nrows=N_ROWS)
df.head()
# Out:
# /var/folders/dy/m0399mcx2q1clz71rv1dbwcm0000gn/T/ipykernel_85027/4186567724.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(CSV_PATH, nrows=N_ROWS)
#     any  mes codi de la regió sanitària regió sanitària grup d'edat  sexe codi del grup ATC nivell 1                 grup ATC nivell 1  \
# 0  2016    1                         61          LLEIDA         0-1  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 1  2016    1                         61          LLEIDA         0-1  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 2  2016    1                         61          LLEIDA         0-1  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 3  2016    1                         61          LLEIDA         0-1  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 4  2016    1                         61          LLEIDA         0-1  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
#
#   codi del grup ATC nivell 2                                  grup ATC nivell 2 codi del grup ATC nivell 3  \
# 0                        A01                         PREPARADOS ESTOMATOLOGICOS                       A01A
# 1                        A02  AGENTES PARA EL TRATAMIENTO DE ALTERACIONES CA...                       A02B
# 2                        A03  AGENTES CONTRA PADECIMIENTOS FUNCIONALES DEL E...                       A03F
# 3                        A07  ANTIDIARREICOS, AGENTES ANTIINFLAMATORIOS/ANTI...                       A07A
# 4                        A07  ANTIDIARREICOS, AGENTES ANTIINFLAMATORIOS/ANTI...                       A07C
#
#                                    grup ATC nivell 3 codi del grup ATC nivell 4                                  grup ATC nivell 4  \
# 0                         PREPARADOS ESTOMATOLOGICOS                      A01AB  Antiinfecciosos y antisepticos para el tratami...
# 1  AGENTES CONTRA LA ULCERA PEPTICA Y EL REFLUJO ...                      A02BC                Inhibidores de la bomba de protones
# 2                                        PROPULSIVOS                      A03FA                                        Propulsivos
# 3                       ANTIINFECCIOSOS INTESTINALES                      A07AA                                       Antibioticos
# 4                     ELECTROLITOS CON CARBOHIDRATOS                      A07CA       Formulaciones de sales de rehidratacion oral
#
#    nombre de receptes  nombre d'envasos  import íntegre  import aportació CatSalut
# 0                  15                15           42.45                      26.04
# 1                   1                 1            2.19                       1.31
# 2                   2                 2            5.00                       3.00
# 3                   6                 6           18.72                      11.22
# 4                  40                40          108.81                      67.61

# %%
df.shape, df.dtypes
# Out:
# ((7828021, 18),
#  any                             int64
#  mes                             int64
#  codi de la regió sanitària     object
#  regió sanitària                object
#  grup d'edat                    object
#  sexe                           object
#  codi del grup ATC nivell 1     object
#  grup ATC nivell 1              object
#  codi del grup ATC nivell 2     object
#  grup ATC nivell 2              object
#  codi del grup ATC nivell 3     object
#  grup ATC nivell 3              object
#  codi del grup ATC nivell 4     object
#  grup ATC nivell 4              object
#  nombre de receptes              int64
#  nombre d'envasos                int64
#  import íntegre                float64
#  import aportació CatSalut     float64
#  dtype: object)

# %%
df.describe()
# Out:
#                 any           mes  nombre de receptes  nombre d'envasos  import íntegre  import aportació CatSalut
# count  7.828021e+06  7.828021e+06        7.828021e+06      7.828021e+06    7.828021e+06               7.828021e+06
# mean   2.020736e+03  6.338038e+00        1.821872e+02      1.822639e+02    2.368167e+03               2.158043e+03
# std    2.923682e+00  3.400331e+00        1.138471e+03      1.139480e+03    1.628385e+04               1.538416e+04
# min    2.016000e+03  1.000000e+00        0.000000e+00      0.000000e+00    0.000000e+00               0.000000e+00
# 25%    2.018000e+03  3.000000e+00        3.000000e+00      3.000000e+00    2.816000e+01               2.172000e+01
# 50%    2.021000e+03  6.000000e+00        1.300000e+01      1.300000e+01    1.357000e+02               1.109000e+02
# 75%    2.023000e+03  9.000000e+00        6.200000e+01      6.200000e+01    7.702100e+02               6.518500e+02
# max    2.025000e+03  1.200000e+01        1.468080e+05      1.468080e+05    3.189276e+06               3.068263e+06

# %%
cat_cols = ["any", "mes", "regió sanitària", "grup d'edat", "sexe", "codi del grup ATC nivell 1", "codi del grup ATC nivell 2", "codi del grup ATC nivell 3", "codi del grup ATC nivell 4"]

for col in cat_cols:
    print(f"\n=== {col} ===")
    print(df[col].value_counts().head(15))
# Out:
# === any ===
# any
# 2024    1106452
# 2025     836001
# 2023     757685
# 2022     747429
# 2018     734803
# 2017     734645
# 2019     733685
# 2016     733130
# 2021     728902
# 2020     715289
# Name: count, dtype: int64
#
# === mes ===
# mes
# 5     680345
# 3     680325
# 7     677722
# 6     676079
# 9     675557
# 1     675190
# 4     673159
# 2     672640
# 8     667725
# 10    585339
# 11    584522
# 12    579418
# Name: count, dtype: int64
#
# === regió sanitària ===
# regió sanitària
# BARCELONA                       1136197
# GIRONA                          1127691
# CAMP DE TARRAGONA               1073267
# CATALUNYA CENTRAL               1033429
# LLEIDA                           959360
# TERRES DE L'EBRE                 852706
# ALT PIRINEU i ARAN               645086
# BARCELONA METROPOLITANA NORD     235625
# BARCELONA CIUTAT                 225806
# BARCELONA METROPOLITANA SUD      215734
# PENEDÈS                          190706
# SENSE ESPECIFICAR                118145
# ALTRES                            14269
# Name: count, dtype: int64
#
# === grup d'edat ===
# grup d'edat
# 65-69    482105
# 60-64    480138
# 70-74    479916
# 55-59    476528
# 85+      474280
# 75-79    470134
# 50-54    469166
# 80-84    455185
# 45-49    454959
# 40-44    436304
# 35-39    405076
# 30-34    369957
# 25-29    337008
# 20-24    314626
# 18-19    238372
# Name: count, dtype: int64
#
# === sexe ===
# sexe
# Dona                 3983286
# Home                 3800664
# Sense especificar      35961
# Altres                  8110
# Name: count, dtype: int64
#
# === codi del grup ATC nivell 1 ===
# codi del grup ATC nivell 1
# N      1393077
# A      1110531
# C       997997
# J       700439
# D       589952
# S       530367
# R       517013
# B       385696
# G       383917
# M       346324
# L       269969
# H       265912
# P       175095
# V        73356
# SES      43052
# Name: count, dtype: int64
#
# === codi del grup ATC nivell 2 ===
# codi del grup ATC nivell 2
# J01    501925
# N05    423789
# S01    402071
# A10    313609
# R03    295875
# N02    288905
# N03    208970
# C09    199114
# N06    182553
# M01    180543
# D07    178389
# G03    171966
# B01    164725
# B03    153159
# C07    152210
# Name: count, dtype: int64
#
# === codi del grup ATC nivell 3 ===
# codi del grup ATC nivell 3
# N05A    258483
# N03A    208970
# A10B    194744
# B01A    164725
# M01A    158221
# J01C    152526
# D07A    140946
# R06A    129513
# N02A    123665
# A10A    118865
# L04A    114093
# N02B    113601
# R03A    109489
# S01E    109071
# C10A    106503
# Name: count, dtype: int64
#
# === codi del grup ATC nivell 4 ===
# codi del grup ATC nivell 4
# N02BE    45125
# M01AE    45054
# J01CA    44055
# R06AX    43928
# J01CR    43894
# H02AB    43635
# R03AC    43616
# D07AC    43155
# J01FA    43133
# SES      43052
# R01AD    42956
# D06AX    42613
# R06AE    42605
# D01AC    42386
# A02BC    42382
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
df.groupby("any")["nombre de receptes"].sum().plot(marker="o")
plt.title("Total prescriptions per year")
plt.ylabel("Number of prescriptions")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,4))
df.groupby("any")["import íntegre"].sum().plot(marker="o")
plt.title("Total billed cost per year (€)")
plt.ylabel("Euros")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,4))
df.groupby("mes")["nombre de receptes"].sum().plot(kind="bar")
plt.title("Seasonality: prescriptions per month")
plt.ylabel("Number of prescriptions")
plt.xlabel("Month")
plt.show()

# %%
cost_region = (
    df.groupby("regió sanitària")["import íntegre"]
      .sum()
      .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))
cost_region.plot(kind="bar")
plt.title("Total cost by health region")
plt.ylabel("Euros")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
df.groupby("regió sanitària")["nombre de receptes"].sum().sort_values().plot(kind="barh")
plt.title("Total prescriptions by region")
plt.xlabel("Number of prescriptions")
plt.show()

# %%
plt.figure(figsize=(8,4))
df.groupby("grup d'edat")["nombre de receptes"].sum().plot(kind="bar")
plt.title("Prescriptions by age group")
plt.ylabel("Number of prescriptions")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,4))
df.groupby("grup d'edat")["import íntegre"].sum().plot(kind="bar")
plt.title("Total cost by age group (€)")
plt.ylabel("Euros")
plt.xticks(rotation=45)
plt.show()

# %%
atc1_cost = (
    df.groupby("grup ATC nivell 1")["import íntegre"]
      .sum()
      .sort_values(ascending=False)
      .head(15)
)

plt.figure(figsize=(10,5))
atc1_cost.plot(kind="bar")
plt.title("Top ATC level 1 groups by cost")
plt.ylabel("Euros")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/dy/m0399mcx2q1clz71rv1dbwcm0000gn/T/ipykernel_85027/4240823135.py:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
plt.figure(figsize=(8,4))
df.groupby("sexe")["nombre de receptes"].sum().plot(kind="bar")
plt.title("Total prescriptions by sex")
plt.ylabel("Number of prescriptions")
plt.show()

# %%
# Total prescriptions per region (normalization denominator)
total_rx_region = df.groupby("regió sanitària")["nombre de receptes"].sum()

# Prescriptions per region × ATC group
region_atc = (
    df.groupby(["regió sanitària", "grup ATC nivell 1"])["nombre de receptes"]
      .sum()
      .reset_index()
)

# Add percentage weight within each region
region_atc["percent_in_region"] = region_atc.apply(
    lambda row: row["nombre de receptes"] / total_rx_region[row["regió sanitària"]],
    axis=1
)

# %%
for region in region_atc["regió sanitària"].unique():
    print("\n=== Region:", region, "===")
    top = (region_atc[region_atc["regió sanitària"] == region]
           .sort_values("percent_in_region", ascending=False)
           .head(10))
    print(top[["grup ATC nivell 1", "percent_in_region"]])
# Out:
# === Region: ALT PIRINEU i ARAN ===
#                              grup ATC nivell 1  percent_in_region
# 10                            SISTEMA NERVIOSO           0.269603
# 7                       SISTEMA CARDIOVASCULAR           0.243739
# 13            TRACTO ALIMENTARIO Y METABOLISMO           0.140052
# 6             SANGRE Y ORGANOS HEMATOPOYETICOS           0.068811
# 11                        SISTEMA RESPIRATORIO           0.052989
# 9                   SISTEMA MUSCULOESQUELETICO           0.050067
# 1           ANTIINFECCIOSOS PARA USO SISTEMICO           0.034186
# 12                           Sense especificar           0.033246
# 3                      ORGANOS DE LOS SENTIDOS           0.032678
# 8   SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.027567
#
# === Region: ALTRES ===
#                      grup ATC nivell 1  percent_in_region
# 26                    SISTEMA NERVIOSO           0.237716
# 16  ANTIINFECCIOSOS PARA USO SISTEMICO           0.132518
# 25          SISTEMA MUSCULOESQUELETICO           0.120895
# 29    TRACTO ALIMENTARIO Y METABOLISMO           0.087914
# 23              SISTEMA CARDIOVASCULAR           0.084404
# 27                SISTEMA RESPIRATORIO           0.083905
# 28                   Sense especificar           0.076487
# 19             ORGANOS DE LOS SENTIDOS           0.041106
# 18                      DERMATOLOGICOS           0.034567
# 22    SANGRE Y ORGANOS HEMATOPOYETICOS           0.030220
#
# === Region: BARCELONA ===
#                              grup ATC nivell 1  percent_in_region
# 41                            SISTEMA NERVIOSO           0.275828
# 38                      SISTEMA CARDIOVASCULAR           0.250458
# 44            TRACTO ALIMENTARIO Y METABOLISMO           0.142122
# 37            SANGRE Y ORGANOS HEMATOPOYETICOS           0.061047
# 42                        SISTEMA RESPIRATORIO           0.054933
# 40                  SISTEMA MUSCULOESQUELETICO           0.044676
# 43                           Sense especificar           0.043059
# 32          ANTIINFECCIOSOS PARA USO SISTEMICO           0.029309
# 39  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.027336
# 34                     ORGANOS DE LOS SENTIDOS           0.022994
#
# === Region: BARCELONA CIUTAT ===
#                              grup ATC nivell 1  percent_in_region
# 56                            SISTEMA NERVIOSO           0.275188
# 53                      SISTEMA CARDIOVASCULAR           0.244900
# 59            TRACTO ALIMENTARIO Y METABOLISMO           0.138778
# 52            SANGRE Y ORGANOS HEMATOPOYETICOS           0.062939
# 57                        SISTEMA RESPIRATORIO           0.057655
# 55                  SISTEMA MUSCULOESQUELETICO           0.043467
# 58                           Sense especificar           0.042171
# 54  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.030888
# 47          ANTIINFECCIOSOS PARA USO SISTEMICO           0.028693
# 49                     ORGANOS DE LOS SENTIDOS           0.023637
#
# === Region: BARCELONA METROPOLITANA NORD ===
#                              grup ATC nivell 1  percent_in_region
# 71                            SISTEMA NERVIOSO           0.284205
# 68                      SISTEMA CARDIOVASCULAR           0.236122
# 74            TRACTO ALIMENTARIO Y METABOLISMO           0.139902
# 72                        SISTEMA RESPIRATORIO           0.060665
# 67            SANGRE Y ORGANOS HEMATOPOYETICOS           0.057285
# 70                  SISTEMA MUSCULOESQUELETICO           0.052407
# 73                           Sense especificar           0.037098
# 69  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.030418
# 62          ANTIINFECCIOSOS PARA USO SISTEMICO           0.029659
# 64                     ORGANOS DE LOS SENTIDOS           0.021038
#
# === Region: BARCELONA METROPOLITANA SUD ===
#                              grup ATC nivell 1  percent_in_region
# 86                            SISTEMA NERVIOSO           0.281601
# 83                      SISTEMA CARDIOVASCULAR           0.243848
# 89            TRACTO ALIMENTARIO Y METABOLISMO           0.140100
# 87                        SISTEMA RESPIRATORIO           0.060121
# 82            SANGRE Y ORGANOS HEMATOPOYETICOS           0.057151
# 85                  SISTEMA MUSCULOESQUELETICO           0.048601
# 88                           Sense especificar           0.035563
# 84  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.030654
# 77          ANTIINFECCIOSOS PARA USO SISTEMICO           0.028069
# 79                     ORGANOS DE LOS SENTIDOS           0.022147
#
# === Region: CAMP DE TARRAGONA ===
#                               grup ATC nivell 1  percent_in_region
# 101                            SISTEMA NERVIOSO           0.269705
# 98                       SISTEMA CARDIOVASCULAR           0.242638
# 104            TRACTO ALIMENTARIO Y METABOLISMO           0.143488
# 97             SANGRE Y ORGANOS HEMATOPOYETICOS           0.057747
# 102                        SISTEMA RESPIRATORIO           0.055602
# 100                  SISTEMA MUSCULOESQUELETICO           0.053692
# 103                           Sense especificar           0.040009
# 92           ANTIINFECCIOSOS PARA USO SISTEMICO           0.032882
# 99   SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.029451
# 94                      ORGANOS DE LOS SENTIDOS           0.024532
#
# === Region: CATALUNYA CENTRAL ===
#                               grup ATC nivell 1  percent_in_region
# 116                            SISTEMA NERVIOSO           0.306889
# 113                      SISTEMA CARDIOVASCULAR           0.231046
# 119            TRACTO ALIMENTARIO Y METABOLISMO           0.139687
# 112            SANGRE Y ORGANOS HEMATOPOYETICOS           0.058989
# 117                        SISTEMA RESPIRATORIO           0.051517
# 115                  SISTEMA MUSCULOESQUELETICO           0.049523
# 118                           Sense especificar           0.033483
# 107          ANTIINFECCIOSOS PARA USO SISTEMICO           0.030245
# 114  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.027616
# 109                     ORGANOS DE LOS SENTIDOS           0.024462
#
# === Region: GIRONA ===
#                               grup ATC nivell 1  percent_in_region
# 131                            SISTEMA NERVIOSO           0.275407
# 128                      SISTEMA CARDIOVASCULAR           0.240365
# 134            TRACTO ALIMENTARIO Y METABOLISMO           0.137273
# 127            SANGRE Y ORGANOS HEMATOPOYETICOS           0.060243
# 132                        SISTEMA RESPIRATORIO           0.054570
# 130                  SISTEMA MUSCULOESQUELETICO           0.050207
# 133                           Sense especificar           0.043374
# 122          ANTIINFECCIOSOS PARA USO SISTEMICO           0.030774
# 129  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.029566
# 124                     ORGANOS DE LOS SENTIDOS           0.023851
#
# === Region: LLEIDA ===
#                               grup ATC nivell 1  percent_in_region
# 146                            SISTEMA NERVIOSO           0.286963
# 143                      SISTEMA CARDIOVASCULAR           0.248089
# 149            TRACTO ALIMENTARIO Y METABOLISMO           0.142227
# 142            SANGRE Y ORGANOS HEMATOPOYETICOS           0.061517
# 147                        SISTEMA RESPIRATORIO           0.052985
# 145                  SISTEMA MUSCULOESQUELETICO           0.047883
# 148                           Sense especificar           0.034358
# 137          ANTIINFECCIOSOS PARA USO SISTEMICO           0.029023
# 144  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.025437
# 139                     ORGANOS DE LOS SENTIDOS           0.024408
#
# === Region: PENEDÈS ===
#                               grup ATC nivell 1  percent_in_region
# 161                            SISTEMA NERVIOSO           0.279437
# 158                      SISTEMA CARDIOVASCULAR           0.236915
# 164            TRACTO ALIMENTARIO Y METABOLISMO           0.142569
# 162                        SISTEMA RESPIRATORIO           0.059661
# 157            SANGRE Y ORGANOS HEMATOPOYETICOS           0.057037
# 160                  SISTEMA MUSCULOESQUELETICO           0.052590
# 163                           Sense especificar           0.033916
# 159  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.031487
# 152          ANTIINFECCIOSOS PARA USO SISTEMICO           0.030044
# 154                     ORGANOS DE LOS SENTIDOS           0.022537
#
# === Region: SENSE ESPECIFICAR ===
#                               grup ATC nivell 1  percent_in_region
# 176                            SISTEMA NERVIOSO           0.262619
# 173                      SISTEMA CARDIOVASCULAR           0.217521
# 179            TRACTO ALIMENTARIO Y METABOLISMO           0.141662
# 175                  SISTEMA MUSCULOESQUELETICO           0.067075
# 177                        SISTEMA RESPIRATORIO           0.064847
# 167          ANTIINFECCIOSOS PARA USO SISTEMICO           0.053147
# 172            SANGRE Y ORGANOS HEMATOPOYETICOS           0.052114
# 174  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.033289
# 178                           Sense especificar           0.028125
# 169                     ORGANOS DE LOS SENTIDOS           0.025739
#
# === Region: TERRES DE L'EBRE ===
#                               grup ATC nivell 1  percent_in_region
# 191                            SISTEMA NERVIOSO           0.276203
# 188                      SISTEMA CARDIOVASCULAR           0.249293
# 194            TRACTO ALIMENTARIO Y METABOLISMO           0.144072
# 187            SANGRE Y ORGANOS HEMATOPOYETICOS           0.057649
# 192                        SISTEMA RESPIRATORIO           0.051189
# 190                  SISTEMA MUSCULOESQUELETICO           0.047830
# 193                           Sense especificar           0.043080
# 189  SISTEMA GENITOURINARIO Y HORMONAS SEXUALES           0.031153
# 182          ANTIINFECCIOSOS PARA USO SISTEMICO           0.030205
# 184                     ORGANOS DE LOS SENTIDOS           0.022919

# %%
import seaborn as sns
import matplotlib.pyplot as plt

heat = region_atc.pivot_table(
    index="regió sanitària",
    columns="grup ATC nivell 1",
    values="percent_in_region"
)

plt.figure(figsize=(14,6))
sns.heatmap(heat, cmap="viridis", annot=False)
plt.title("Medication profile by region (ATC Level 1 % share)")
plt.ylabel("Region")
plt.xlabel("ATC group")
plt.show()

# %%
month_atc = (
    df.groupby(["mes", "grup ATC nivell 1"])["nombre de receptes"]
      .sum()
      .reset_index()
)

# %%
top_atc = (
    df.groupby("grup ATC nivell 1")["nombre de receptes"]
      .sum()
      .sort_values(ascending=False)
      .head(6)
      .index
)

plt.figure(figsize=(10,6))
for atc in top_atc:
    sub = month_atc[month_atc["grup ATC nivell 1"] == atc]
    plt.plot(sub["mes"], sub["nombre de receptes"], marker="o", label=atc)

plt.title("Monthly prescription seasonality by ATC group")
plt.xlabel("Month")
plt.ylabel("Number of prescriptions")
plt.legend()
plt.grid(True)
plt.show()

# %%
region_atc_matrix = region_atc.pivot_table(
    index="regió sanitària",
    columns="grup ATC nivell 1",
    values="percent_in_region",
    fill_value=0
)

corr = region_atc_matrix.T.corr()  # region×region correlation

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation of medication profiles between regions")
plt.show()

# %% [markdown]
# No region is “special” in terms of ATC usage.
#
# The medication burden is dominated by chronic diseases (cardiovascular, nervous system, diabetes).
#
# Only respiratory drugs show clear seasonal variation.
#
# Correlation matrix confirms: regional therapeutic patterns are nearly identical.
# Possible causes:
# - Uniform healthcare practices
# - Similar population structure across regions
# - Universal coverage system prescribing the same guidelines
# - Aggregated ATC Level 1 categories are too coarse to reveal fine differences

# %% [markdown]
# ## nervioso

# %%
df_nerv = df[df["grup ATC nivell 1"] == "SISTEMA NERVIOSO"].copy()
df_nerv.shape
# Out:
# (1393077, 18)

# %%
lvl2 = (
    df_nerv.groupby("grup ATC nivell 2")["nombre de receptes"]
           .sum()
           .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))
lvl2.plot(kind="bar")
plt.title("Distribution of ATC Level 2 categories in SISTEMA NERVIOSO")
plt.ylabel("Number of prescriptions")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
lvl3 = (
    df_nerv.groupby("grup ATC nivell 3")["nombre de receptes"]
           .sum()
           .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))
lvl3.head(15).plot(kind="bar")
plt.title("Top ATC Level 3 categories in SISTEMA NERVIOSO")
plt.ylabel("Number of prescriptions")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
(
    df_nerv.groupby("grup d'edat")["nombre de receptes"]
           .sum()
           .sort_values(ascending=False)
           .plot(kind="bar")
)
plt.title("Nervous system prescriptions by age group")
plt.ylabel("Number of prescriptions")
plt.xticks(rotation=45)
plt.show()

# %%
age_lvl2 = df_nerv.groupby(["grup d'edat", "grup ATC nivell 2"])["nombre de receptes"].sum()

heat_age_lvl2 = age_lvl2.unstack().fillna(0)

plt.figure(figsize=(12,6))
sns.heatmap(heat_age_lvl2, cmap="viridis")
plt.title("Age × ATC Level 2 usage in SISTEMA NERVIOSO")
plt.show()

# %%
gender_lvl2 = (
    df_nerv.groupby(["sexe", "grup ATC nivell 2"])["nombre de receptes"]
           .sum()
           .unstack()
)

gender_lvl2.plot(kind="bar", figsize=(12,5))
plt.title("Gender differences in ATC Level 2 (Nervous System)")
plt.ylabel("Number of prescriptions")
plt.xticks(rotation=0)
plt.show()

# %%
region_lvl2 = (
    df_nerv.groupby(["regió sanitària", "grup ATC nivell 2"])["nombre de receptes"]
           .sum()
           .unstack()
)

plt.figure(figsize=(14,6))
sns.heatmap(region_lvl2.div(region_lvl2.sum(axis=1), axis=0), cmap="viridis")
plt.title("Regional ATC Level 2 medication mix (normalized)")
plt.xlabel("ATC Level 2")
plt.ylabel("Region")
plt.show()

# %%
monthly_lvl2 = (
    df_nerv.groupby(["mes", "grup ATC nivell 2"])["nombre de receptes"]
           .sum()
           .reset_index()
)

plt.figure(figsize=(10,6))

top_lvl2 = lvl2.head(4).index  # top 4 Level 2 groups

for l2 in top_lvl2:
    sub = monthly_lvl2[monthly_lvl2["grup ATC nivell 2"] == l2]
    plt.plot(sub["mes"], sub["nombre de receptes"], marker="o", label=l2)

plt.title("Monthly seasonality for top Level 2 groups (Nervous System)")
plt.ylabel("Number of prescriptions")
plt.xlabel("Month")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Main conclusion:
#
# There are major gender disparities in nervous-system medication use.
#
# Observations; Women (Dona):
#
# Substantially higher use of:
# - Psychoanaleptics (N06) → antidepressants
# - Psycholeptics (N05) → anxiolytics, sedatives
#
# Also somewhat higher in:
# - Analgesics (N02) → chronic pain medications

# %% [markdown]
# Gender is a major differentiator in nervous-system drug use, far stronger than:
# - Region
# - Month
# - Often stronger than age for some categories
#
# This suggests:
# - Differences in disease prevalence
# - Differences in diagnosis rates
# - Differences in prescribing practices
# - Known global patterns in mental-health pharmacology
