# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make tables easier to read
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 140)

CSV_PATH = "data.csv"

# %%
N_ROWS = None
df = pd.read_csv(CSV_PATH, nrows=N_ROWS)
df.head()
# Out:
# C:\Users\gerar\AppData\Local\Temp\ipykernel_11680\1138973836.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(CSV_PATH, nrows=N_ROWS)
#     any  mes codi de la regió sanitària regió sanitària grup d'edat  sexe codi del grup ATC nivell 1                 grup ATC nivell 1  \
# 0  2025    9                         61          LLEIDA     0-1 any  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 1  2025    9                         61          LLEIDA     0-1 any  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 2  2025    9                         61          LLEIDA     0-1 any  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 3  2025    9                         61          LLEIDA     0-1 any  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 4  2025    9                         61          LLEIDA     0-1 any  Dona                          A  TRACTO ALIMENTARIO Y METABOLISMO
#
#   codi del grup ATC nivell 2                                  grup ATC nivell 2 codi del grup ATC nivell 3  \
# 0                        A01                         PREPARADOS ESTOMATOLOGICOS                       A01A
# 1                        A02  AGENTES PARA EL TRATAMIENTO DE ALTERACIONES CA...                       A02B
# 2                        A07  ANTIDIARREICOS, AGENTES ANTIINFLAMATORIOS/ANTI...                       A07A
# 3                        A07  ANTIDIARREICOS, AGENTES ANTIINFLAMATORIOS/ANTI...                       A07C
# 4                        A11                                          VITAMINAS                       A11C
#
#                                    grup ATC nivell 3 codi del grup ATC nivell 4                                  grup ATC nivell 4  \
# 0                         PREPARADOS ESTOMATOLOGICOS                      A01AB  Antiinfecciosos y antisepticos para el tratami...
# 1  AGENTES CONTRA LA ULCERA PEPTICA Y EL REFLUJO ...                      A02BC                Inhibidores de la bomba de protones
# 2                       ANTIINFECCIOSOS INTESTINALES                      A07AA                                       Antibioticos
# 3                     ELECTROLITOS CON CARBOHIDRATOS                      A07CA       Formulaciones de sales de rehidratacion oral
# 4  VITAMINAS A Y D, INCLUYENDO COMBINACIONES DE L...                      A11CC                              Vitamina D y analogos
#
#    nombre de receptes  nombre d'envasos import íntegre import aportació CatSalut
# 0                 3.0               3.0           8,49                      7,36
# 1                 1.0               1.0          17,75                     10,65
# 2                17.0              17.0          79,56                     53,84
# 3                27.0              27.0          95,62                     56,26
# 4               307.0             307.0       1.708,00                  1.036,48

# %%
bad_values = ["Sense especificar", "Altres", "ALTRES", "SENSE ESPECIFICAR", "VARIOS"]

df = df.dropna()                     # remove NaNs
df = df[~df.isin(bad_values).any(axis=1)]

# %%
df.to_csv("clean_data.csv", index = False)

# %%
cat_cols = ["any", "mes", "regió sanitària", "grup d'edat", "sexe", "grup ATC nivell 1", "grup ATC nivell 2", "grup ATC nivell 3", "grup ATC nivell 4"]

for col in cat_cols:
    print(f"\n=== {col} ===")
    print(df[col].value_counts().head(15))
# Out:
# === any ===
# any
# 2024    1076471
# 2025     811640
# 2023     731941
# 2022     722620
# 2021     708041
# 2019     703674
# 2018     700724
# 2017     697541
# 2016     693104
# 2020     690616
# Name: count, dtype: int64
#
# === mes ===
# mes
# 5     655344
# 3     654966
# 7     653388
# 6     651516
# 4     648553
# 2     647940
# 9     647692
# 1     647386
# 8     643786
# 10    563612
# 11    563386
# 12    558803
# Name: count, dtype: int64
#
# === regió sanitària ===
# regió sanitària
# BARCELONA                       1108507
# GIRONA                          1104394
# CAMP DE TARRAGONA               1051641
# CATALUNYA CENTRAL               1012781
# LLEIDA                           938956
# TERRES DE L'EBRE                 836848
# ALT PIRINEU i ARAN               633534
# BARCELONA METROPOLITANA NORD     230473
# BARCELONA CIUTAT                 220916
# BARCELONA METROPOLITANA SUD      211358
# PENEDÈS                          186964
# Name: count, dtype: int64
#
# === grup d'edat ===
# grup d'edat
# 65-69 anys        237661
# 70-74 anys        237215
# 60-64 anys        237123
# 55-59 anys        236142
# 75-79 anys        233937
# 50-54 anys        232342
# 18-19 anys        231059
# 65-69             229188
# 70-74             228122
# 60-64             227197
# 55-59             225731
# 45-49 anys        225015
# Més de 84 anys    224528
# 80-84 anys        224207
# 16-17 anys        222587
# Name: count, dtype: int64
#
# === sexe ===
# sexe
# Dona    3854766
# Home    3681606
# Name: count, dtype: int64
#
# === grup ATC nivell 1 ===
# grup ATC nivell 1
# SISTEMA NERVIOSO                                                              1366834
# TRACTO ALIMENTARIO Y METABOLISMO                                              1093443
# SISTEMA CARDIOVASCULAR                                                         977851
# ANTIINFECCIOSOS PARA USO SISTEMICO                                             688916
# DERMATOLOGICOS                                                                 582585
# ORGANOS DE LOS SENTIDOS                                                        524019
# SISTEMA RESPIRATORIO                                                           506250
# SANGRE Y ORGANOS HEMATOPOYETICOS                                               378460
# SISTEMA GENITOURINARIO Y HORMONAS SEXUALES                                     377028
# SISTEMA MUSCULOESQUELETICO                                                     338677
# AGENTES ANTINEOPLASICOS E INMUNOMODULADORES                                    267287
# PREPARADOS HORMONALES SISTEMICOS, EXCLUYENDO HORMONAS SEXUALES E INSULINAS     261554
# PRODUCTOS ANTIPARASITARIOS, INSECTICIDAS Y REPELENTES                          173468
# Name: count, dtype: int64
#
# === grup ATC nivell 2 ===
# grup ATC nivell 2
# ANTIBACTERIANOS PARA USO SISTEMICO                                     492813
# PSICOLEPTICOS                                                          416623
# OFTALMOLOGICOS                                                         397128
# FARMACOS USADOS EN DIABETES                                            307590
# AGENTES CONTRA PADECIMIENTOS OBSTRUCTIVOS DE LAS VIAS RESPIRATORIAS    290213
# ANALGESICOS                                                            280926
# ANTIEPILEPTICOS                                                        205872
# AGENTES QUE ACTUAN SOBRE EL SISTEMA RENINA-ANGIOTENSINA                193372
# PSICOANALEPTICOS                                                       177347
# PREPARADOS DERMATOLOGICOS CON CORTICOSTEROIDES                         176182
# PRODUCTOS ANTIINFLAMATORIOS Y ANTIRREUMATICOS                          175679
# HORMONAS SEXUALES Y MODULADORES DEL SISTEMA GENITAL                    168475
# AGENTES ANTITROMBOTICOS                                                161014
# PREPARADOS ANTIANEMICOS                                                150272
# TERAPIA CARDIACA                                                       150076
# Name: count, dtype: int64
#
# === grup ATC nivell 3 ===
# grup ATC nivell 3
# ANTIPSICOTICOS                                                  255411
# ANTIEPILEPTICOS                                                 205872
# FARMACOS HIPOGLUCEMIANTES EXCLUYENDO INSULINAS                  190529
# AGENTES ANTITROMBOTICOS                                         161014
# PRODUCTOS ANTIINFLAMATORIOS Y ANTIRREUMATICOS NO ESTEROIDEOS    153538
# ANTIBACTERIANOS BETALACTAMICOS, PENICILINAS                     148504
# CORTICOSTEROIDES, MONOFARMACOS                                  138998
# ANTIHISTAMINICOS PARA USO SISTEMICO                             126166
# ANTIINFECCIOSOS                                                 121594
# OPIOIDES                                                        121002
# INSULINAS Y ANALOGOS                                            117061
# INMUNOSUPRESORES                                                113031
# OTROS ANALGESICOS Y ANTIPIRETICOS                               109058
# PREPARADOS CONTRA EL GLAUCOMA Y MIOTICOS1)                      107342
# ADRENERGICOS, INHALATORIOS                                      106499
# Name: count, dtype: int64
#
# === grup ATC nivell 4 ===
# grup ATC nivell 4
# Corticosteroides y antiinfecciosos en combinacion                           111718
# Derivados de la benzodiazepina                                              106528
# Antibioticos                                                                104392
# Anticolinergicos                                                             64977
# Agonistas selectivos de receptores beta-2 adrenergicos                       62228
# Corticosteroides                                                             62151
# Biguanidas                                                                   50250
# Sulfonamidas, monofarmacos                                                   47552
# Glucocorticoides                                                             44975
# Derivados del acido propionico                                               42332
# Anilidas                                                                     42325
# Penicilinas con espectro ampliado                                            42311
# Combinaciones de penicilinas, incluyendo inhibidores de la betalactamasa     42262
# Otros antihistaminicos para uso sistemico                                    42248
# Corticosteroides potentes (grupo III)                                        42047
# Name: count, dtype: int64
