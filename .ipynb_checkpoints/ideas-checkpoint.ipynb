# %% [markdown]
# #### Mental health

# %% [markdown]
# Do Sun/weather have impact on mental health? (classified by region)
# - comapre sunny days and # of prescriptions
# - comapre sunny days and # if hospitalisations

# %% [markdown]
# In which way goverment invest in metal health?
# - numuer of psycologist
# - funded drugs

# %% [markdown]
# More developed cities more mental health problems?
# Cities near water less mh problems?

# %% [markdown]
# Age and sex?

# %% [markdown]
# Is middle age people from cities getting more mhp that from viliges?

# %% [markdown]
# Time? (maybe we are getting more isolated with time following new tehnology)

# %% [markdown]
# Covid (isolation) and mhp?

# %% [markdown]
# addictions- AD used in this situation?
