# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("analisi.transparenciacatalunya.cat", None)
print("Format of dataset: ", type(client))
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
# from: https://analisi.transparenciacatalunya.cat/api/v3/views/euku-fzbx/query.json
results = client.get("thrd-jj3r", limit=20000) # 2000 is the number of rows that we scrape from the web page

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.columns
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Format of dataset:  <class 'sodapy.socrata.Socrata'>
# Index(['any', 'mes', 'codi_regio_sanitaria', 'regio_sanitaria', 'grup_edat',
#        'sexe', 'codi_atc_1', 'atc_1', 'codi_atc_2', 'atc_2', 'codi_atc_3',
#        'atc_3', 'codi_atc_4', 'atc_4', 'nombre_receptes', 'nombre_envasos',
#        'import_integre', 'aportacio_catsalut'],
#       dtype='object')

# %%
import numpy as np

100*np.sum(results_df['aportacio_catsalut'].astype('float'))/np.sum(results_df['import_integre'].astype('float'))
# Out:
# np.float64(91.83725169757484)

# %%
results_df['atc_3'].unique()
# Out:
# array(['PREPARADOS ESTOMATOLOGICOS',
#        'AGENTES CONTRA LA ULCERA PEPTICA Y EL REFLUJO GASTROESOFAGICO (RGE/GORD)',
#        'ANTIINFECCIOSOS INTESTINALES', 'ELECTROLITOS CON CARBOHIDRATOS',
#        'VITAMINAS A Y D, INCLUYENDO COMBINACIONES DE LAS DOS',
#        'VITAMINA B1, SOLA Y EN COMBINACION CON VITAMINAS B6 Y B12',
#        'OTROS PREPARADOS DE VITAMINAS, MONOFARMACOS',
#        'AGENTES ANTITROMBOTICOS', 'SOLUCIONES I.V.',
#        'ESTIMULANTES CARDIACOS EXCLUYENDO GLUCOSIDOS CARDIACOS',
#        'DIURETICOS DE TECHO ALTO', 'AGENTES BETA-BLOQUEANTES',
#        'INHIBIDORES DE LA ECA, MONOFARMACOS',
#        'ANTIFUNGICOS PARA USO TOPICO', 'ANTIBIOTICOS PARA USO TOPICO',
#        'CORTICOSTEROIDES, MONOFARMACOS', 'Sense especificar',
#        'ESTROGENOS', 'CORTICOSTEROIDES PARA USO SISTEMICO, MONOFARMACOS',
#        'ANTIBACTERIANOS BETALACTAMICOS, PENICILINAS',
#        'OTROS ANTIBACTERIANOS BETALACTAMICOS',
# ...
