# %%
import pandas as pd

# ================================
# Step 1: Load the CSV safely
# ================================
# Try UTF-8 first; if it fails, fallback to latin1

file_path = 'Dataset.csv'
file_path2 = 'Ad_dataset.csv'

try:
    df = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='latin1')

ef = pd.read_csv(file_path2)

print(ef.index, "\n")

# Show the first rows to check everything loaded correctly
print("First 5 rows of your data:")
print(df.head(), "\n")

# ================================
# Step 2: Clean column names (optional)
# ================================
# Remove extra spaces and fix encoding issues in column names
df.columns = [col.strip().replace('Ã ', 'à').replace('Ã©', 'é') for col in df.columns]
print("Columns after cleaning:")
print(df.columns, "\n")

# ================================
# Step 3: Quick summary of data
# ================================
print("Basic info about the dataset:")
print(df.info())
print("\nDescriptive statistics for numeric columns:")
print(df.describe(), "\n")
# Out:
# C:\Users\ismar\AppData\Local\Temp\ipykernel_3768\1109332179.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# RangeIndex(start=0, stop=379, step=1)
#
# First 5 rows of your data:
#     any  mes codi de la regió sanitària regió sanitària grup d'edat  sexe  \
# 0  2025    9                         61          LLEIDA     0-1 any  Dona
# 1  2025    9                         61          LLEIDA     0-1 any  Dona
# 2  2025    9                         61          LLEIDA     0-1 any  Dona
# 3  2025    9                         61          LLEIDA     0-1 any  Dona
# 4  2025    9                         61          LLEIDA     0-1 any  Dona
#
#   codi del grup ATC nivell 1                 grup ATC nivell 1  \
# 0                          A  TRACTO ALIMENTARIO Y METABOLISMO
# 1                          A  TRACTO ALIMENTARIO Y METABOLISMO
# ...
